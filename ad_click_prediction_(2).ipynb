# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
warnings.filterwarnings("ignore")

# %%
df=pd.read_csv("advertising_data.csv")
df.head()
# Out:
#    Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                     68.95   35     61833.90                256.09
# 1                     80.23   31     68441.85                193.77
# 2                     69.47   26     59785.94                236.50
# 3                     74.15   29     54806.18                245.89
# 4                     68.37   35     73889.99                225.58
#
#                            Ad Topic Line            City  Male     Country  \
# 0     Cloned 5thgeneration orchestration     Wrightburgh     0     Tunisia
# 1     Monitored national standardization       West Jodi     1       Nauru
# 2       Organic bottom-line service-desk        Davidton     0  San Marino
# 3  Triple-buffered reciprocal time-frame  West Terrifurt     1       Italy
# 4          Robust logistical utilization    South Manuel     0     Iceland
#
#          Timestamp  Clicked on Ad
# 0   3/27/2016 0:53              0
# 1    4/4/2016 1:39              0
# ...

# %%
df.shape
# Out:
# (1000, 10)
# (1000, 10)

# %% [markdown]
# data cleaning

# %%
df.describe()
# Out:
#        Daily Time Spent on Site          Age    Area Income  \
# count               1000.000000  1000.000000    1000.000000
# mean                  65.000200    36.009000   55868.450080
# std                   15.853615     8.785562   26295.327717
# min                   32.600000    19.000000    1000.540000
# 25%                   51.360000    29.000000   47117.162500
# 50%                   68.215000    35.000000   57023.600000
# 75%                   78.547500    42.000000   65497.567500
# max                   91.430000    61.000000  713841.570000
#
#        Daily Internet Usage         Male  Clicked on Ad
# count           1000.000000  1000.000000     1000.00000
# mean             180.000100     0.481000        0.50000
# std               43.902339     0.499889        0.50025
# min              104.780000     0.000000        0.00000
# 25%              138.830000     0.000000        0.00000
# 50%              183.130000     0.000000        0.50000
# ...

# %%
sns.boxplot(df[["Daily Time Spent on Site","Age","Daily Internet Usage","Male"]])
# Out:
# <Axes: >
# <Axes: >

# %%
sns.boxplot(df["Area Income"])
# Out:
# <Axes: ylabel='Area Income'>
# <Axes: ylabel='Area Income'>

# %%
def remove_outliers(df):
  q1=df.quantile(0.25)
  q3=df.quantile(0.75)
  IQR=q3-q1
  low_L=q1-1.5*IQR
  upper_l=q3+1.5*IQR
  data=df[((df>=low_L)&(df<=upper_l))]
  return data

df["Area Income"]=remove_outliers(df["Area Income"])
sns.boxplot(df["Area Income"])
df.dropna(inplace=True)
df=df.reset_index(drop=True)
df
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  \
# 0                       68.95   35     61833.90                256.09
# 1                       80.23   31     68441.85                193.77
# 2                       69.47   26     59785.94                236.50
# 3                       74.15   29     54806.18                245.89
# 4                       68.37   35     73889.99                225.58
# ..                        ...  ...          ...                   ...
# 982                     64.20   27     66200.96                227.63
# 983                     43.70   28     63126.96                173.01
# 984                     51.30   45     67782.17                134.42
# 985                     51.63   51     42415.72                120.37
# 986                     45.01   26     29875.80                178.35
#
#                              Ad Topic Line            City  Male  \
# ...

# %%
data=df.drop(df[["Timestamp","Ad Topic Line","City","Country"]],axis="columns")
data
# Out:
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male  \
# 0                       68.95   35     61833.90                256.09     0
# 1                       80.23   31     68441.85                193.77     1
# 2                       69.47   26     59785.94                236.50     0
# 3                       74.15   29     54806.18                245.89     1
# 4                       68.37   35     73889.99                225.58     0
# ..                        ...  ...          ...                   ...   ...
# 982                     64.20   27     66200.96                227.63     1
# 983                     43.70   28     63126.96                173.01     0
# 984                     51.30   45     67782.17                134.42     1
# 985                     51.63   51     42415.72                120.37     1
# 986                     45.01   26     29875.80                178.35     0
#
#      Clicked on Ad
# 0                0
# ...

# %%
data.isnull().sum()
# Out:
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Male                        0
# Clicked on Ad               0
# dtype: int64
# Daily Time Spent on Site    0
# Age                         0
# Area Income                 0
# Daily Internet Usage        0
# Male                        0
# Clicked on Ad               0
# dtype: int64

# %% [markdown]
# EDA

# %%
a=["Age","Area Income","Daily Internet Usage","Male","Clicked on Ad"]
sns.set_palette("pastel")
sns.set_style('whitegrid')
for i in a:
  plt.hist(data[i])
  plt.xlabel(i)
  plt.ylabel("frequancy")
  plt.show()

# %%
plt.figure(figsize=(17,5))
plt.subplot(151)
sns.distplot(data[data["Clicked on Ad"]==0]["Age"],hist=False,label="not clicked")
sns.distplot(data[data["Clicked on Ad"]==1]["Age"],hist=False,label="clicked")
plt.legend()
plt.subplot(152)
sns.distplot(data[data["Clicked on Ad"]==0]["Daily Time Spent on Site"],hist=False,label="not clicked")
sns.distplot(data[data["Clicked on Ad"]==1]["Daily Time Spent on Site"],hist=False,label="clicked")
plt.subplot(153)
sns.distplot(data[data["Clicked on Ad"]==0]["Area Income"],hist=False,label="not clicked")
sns.distplot(data[data["Clicked on Ad"]==1]["Area Income"],hist=False,label="clicked")
plt.subplot(154)
sns.distplot(data[data["Clicked on Ad"]==0]["Daily Internet Usage"],hist=False,label="not clicked")
sns.distplot(data[data["Clicked on Ad"]==1]["Daily Internet Usage"],hist=False,label="clicked")
plt.subplot(155)
sns.distplot(data[data["Clicked on Ad"]==0]["Male"],hist=False,label="not clicked")
sns.distplot(data[data["Clicked on Ad"]==1]["Male"],hist=False,label="clicked")
# Out:
# <Axes: xlabel='Male', ylabel='Density'>
# <Axes: xlabel='Male', ylabel='Density'>

# %%
sns.pairplot(data,hue="Clicked on Ad",palette="Set1")

# %%
cr=data.corr()
sns.heatmap(cr,annot=True)
# Out:
# <Axes: >
# <Axes: >

# %% [markdown]
# min max scalar

# %%
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import PowerTransformer,StandardScaler,FunctionTransformer
x=data.drop(["Clicked on Ad"],axis="columns")
y=data["Clicked on Ad"]
print(f"{y.head()}")
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.3,random_state=10)
x_train.head()
# Out:
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Clicked on Ad, dtype: int64
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male
# 132                     43.49   47     50335.46                127.83     0
# 87                      56.89   37     37334.78                109.29     1
# 292                     82.40   36     66744.65                218.97     1
# 426                     88.72   32     43870.51                211.87     1
# 237                     80.03   44     24030.06                150.84     0
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# Name: Clicked on Ad, dtype: int64
#      Daily Time Spent on Site  Age  Area Income  Daily Internet Usage  Male
# 132                     43.49   47     50335.46                127.83     0
# 87                      56.89   37     37334.78                109.29     1
# 292                     82.40   36     66744.65                218.97     1
# ...

# %%
data["Area Income"].skew()
# Out:
# -0.5750714917159899
# -0.5750714917159899

# %%
trf=PowerTransformer()
trf_1=FunctionTransformer()
x_train_trans=x_train
x_test_trans=x_test
x_train_trans["Area Income"]=trf.fit_transform(x_train[["Area Income"]])
x_test_trans["Area Income"]=trf.transform(x_test[["Area Income"]])
x_train_trans["Age"]=trf.fit_transform(x_train[["Age"]])
x_test_trans["Age"]=trf.transform(x_test[["Age"]])
x_train_trans.head()
data_final=pd.DataFrame(x_train_trans,columns=x_train_trans.columns).reset_index(drop=True)

# %%
scaler=StandardScaler()
x_train_scaled=scaler.fit_transform(x_train_trans)
x_test_scaled=scaler.transform(x_test_trans)
x_train_scaled=np.round(x_train_scaled,2)
x_test_scaled=np.round(x_test_scaled,2)
data_1=pd.DataFrame(x_train_scaled,columns=x_train.columns)
data_1.head()
# Out:
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  Male
# 0                     -1.35  1.26        -0.52                 -1.20 -0.96
# 1                     -0.51  0.28        -1.39                 -1.63  1.04
# 2                      1.10  0.16         0.89                  0.88  1.04
# 3                      1.49 -0.33        -0.98                  0.71  1.04
# 4                      0.95  0.99        -2.04                 -0.68 -0.96
#    Daily Time Spent on Site   Age  Area Income  Daily Internet Usage  Male
# 0                     -1.35  1.26        -0.52                 -1.20 -0.96
# 1                     -0.51  0.28        -1.39                 -1.63  1.04
# 2                      1.10  0.16         0.89                  0.88  1.04
# 3                      1.49 -0.33        -0.98                  0.71  1.04
# 4                      0.95  0.99        -2.04                 -0.68 -0.96

# %%
from sklearn.linear_model import LogisticRegression
from sklearn import tree
from sklearn.svm import SVC
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import confusion_matrix
from sklearn.model_selection import GridSearchCV

# %%
para={"para_regg":{"C":[1,10,20,30],"penalty":["l1","l2"],"max_iter":[50,100,200,300],"solver":["liblinear", "lbfgs," "saga"]},
      "para_dec":{"criterion":["gini","entropy"],"max_depth":[None,10,5,20],"max_features":[None,1,2]},
      "para_ran":{"n_estimators":[10,20,50,100,500],"max_depth":[2,50,100,200,500]},
      "para_SVM":{"C":[1,2,5,10,20,50],"kernel":["linear","poly","rbf"]}
      }

# %%
clf_reg=GridSearchCV(LogisticRegression(),para.get("para_regg"),cv=10)
clf_reg.fit(x,y)
# Out:
# GridSearchCV(cv=10, estimator=LogisticRegression(),
#              param_grid={'C': [1, 10, 20, 30], 'max_iter': [50, 100, 200, 300],
#                          'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear', 'lbfgs,saga']})
# GridSearchCV(cv=10, estimator=LogisticRegression(),
#              param_grid={'C': [1, 10, 20, 30], 'max_iter': [50, 100, 200, 300],
#                          'penalty': ['l1', 'l2'],
#                          'solver': ['liblinear', 'lbfgs,saga']})

# %%
p=round(clf_reg.best_score_,3)
p
# Out:
# 0.972
# 0.973

# %%
a=clf_reg.best_params_
a
# Out:
# {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'solver': 'liblinear'}
# {'C': 20, 'max_iter': 200, 'penalty': 'l1', 'solver': 'liblinear'}

# %%
clf_dec=GridSearchCV(tree.DecisionTreeClassifier(),para.get("para_dec"),cv=10)
clf_dec.fit(x,y)
# Out:
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 5, 20],
#                          'max_features': [None, 1, 2]})
# GridSearchCV(cv=10, estimator=DecisionTreeClassifier(),
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [None, 10, 5, 20],
#                          'max_features': [None, 1, 2]})

# %%
q=round(clf_dec.best_score_,3)
q
# Out:
# 0.956
# 0.956

# %%
b=clf_dec.best_params_
b
# Out:
# {'criterion': 'gini', 'max_depth': 5, 'max_features': None}
# {'criterion': 'entropy', 'max_depth': None, 'max_features': 2}

# %%
clf_ran=GridSearchCV(RandomForestClassifier(),para.get("para_ran"),cv=10)
clf_ran.fit(x,y)
# Out:
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 50, 100, 200, 500],
#                          'n_estimators': [10, 20, 50, 100, 500]})
# GridSearchCV(cv=10, estimator=RandomForestClassifier(),
#              param_grid={'max_depth': [2, 50, 100, 200, 500],
#                          'n_estimators': [10, 20, 50, 100, 500]})

# %%
r=round(clf_ran.best_score_,3)
r
# Out:
# 0.966
# 0.966

# %%
c=clf_ran.best_params_
c
# Out:
# {'max_depth': 50, 'n_estimators': 20}
# {'max_depth': 100, 'n_estimators': 20}

# %%
clf_SVM=GridSearchCV(SVC(),para.get("para_SVM"),cv=10)
clf_SVM.fit(x,y)
# Out:
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid={'C': [1, 2, 5, 10, 20, 50],
#                          'kernel': ['linear', 'poly', 'rbf']})
# GridSearchCV(cv=10, estimator=SVC(),
#              param_grid={'C': [1, 2, 5, 10, 20, 50],
#                          'kernel': ['linear', 'poly', 'rbf']})

# %%
s=round(clf_SVM.best_score_,3)
s
# Out:
# 0.973
# 0.973

# %%
d=clf_SVM.best_params_
d
# Out:
# {'C': 5, 'kernel': 'linear'}
# {'C': 5, 'kernel': 'linear'}

# %%
from tabulate import tabulate
LIST_=[["Logistic Regression",a,p],["DecisionTreeClassifier",b,q],
 ["RandomForestClassifier",c,r],["SVC",d,s]]
headers=["MODEL","BEST PARAMETER","ACCURACY"]
print(tabulate(LIST_, headers=headers, tablefmt="grid"))
# Out:
# +------------------------+------------------------------------------------------------------+------------+
# | MODEL                  | BEST PARAMETER                                                   |   ACCURACY |
# +========================+==================================================================+============+
# | Logistic Regression    | {'C': 1, 'max_iter': 50, 'penalty': 'l1', 'solver': 'liblinear'} |      0.972 |
# +------------------------+------------------------------------------------------------------+------------+
# | DecisionTreeClassifier | {'criterion': 'gini', 'max_depth': 5, 'max_features': None}      |      0.955 |
# +------------------------+------------------------------------------------------------------+------------+
# | RandomForestClassifier | {'max_depth': 50, 'n_estimators': 20}                            |      0.966 |
# +------------------------+------------------------------------------------------------------+------------+
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=20)
y_train
# Out:
# 359    0
# 156    1
# 446    1
# 965    1
# 585    1
#       ..
# 924    0
# 223    1
# 271    0
# 474    1
# 355    1
# Name: Clicked on Ad, Length: 789, dtype: int64
# 359    0
# 156    1
# 446    1
# 965    1
# 585    1
#       ..
# 924    0
# 223    1
# 271    0
# 474    1
# 355    1
# Name: Clicked on Ad, Length: 789, dtype: int64

# %%
model=LogisticRegression(C=1, max_iter=50, penalty='l1', solver='liblinear')
model.fit(x_train,y_train)
# Out:
# LogisticRegression(C=1, max_iter=50, penalty='l1', solver='liblinear')

# %%
model.score(x_test,y_test)
# Out:
# 0.9663299663299664

# %%
y_predict=model.predict(x_test)
cm=confusion_matrix(y_test,y_predict)
sns.heatmap(cm,annot=True,fmt='d')
plt.xlabel("predicted")
plt.ylabel("Truth")
# Out:
# Text(50.722222222222214, 0.5, 'Truth')

# %%
from sklearn.metrics import classification_report
cl=classification_report(y_test,y_predict)
print(cl)
# Out:
#               precision    recall  f1-score   support
#
#            0       0.93      1.00      0.97       139
#            1       1.00      0.94      0.97       158
#
#     accuracy                           0.97       297
#    macro avg       0.97      0.97      0.97       297
# weighted avg       0.97      0.97      0.97       297
